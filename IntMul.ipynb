# %%
import sympy as sp

def multiple_integral(expression, variables, limits):
    symbols = sp.symbols(variables)
    integral_expr = expression
    for i, limit in enumerate(limits):
        if limit[1] is None:
            integral_expr = sp.integrate(integral_expr, (symbols[i], limit[0]))
        else:
            integral_expr = sp.integrate(integral_expr, (symbols[i], limit[0], limit[1]))
    return integral_expr

def main():
    expression = sp.sympify(input("Ingrese la expresión a integrar: "))
    num_variables = int(input("Ingrese el número de variables de integración: "))
    variables = []
    for i in range(num_variables):
        variable = input(f"Ingrese el nombre de la variable {i + 1}: ")
        variables.append(variable)
    num_limits = int(input("Ingrese el número de límites de integración: "))
    limits = []
    for i in range(num_limits):
        limit_type = input(f"Ingrese el tipo de límite (indefinido o definido) {i + 1}: ")
        if limit_type.lower() == "indefinido":
            limits.append((None, None))
        elif limit_type.lower() == "definido":
            lower_limit = float(input(f"Ingrese el límite inferior {i + 1}: "))
            upper_limit = float(input(f"Ingrese el límite superior {i + 1}: "))
            limits.append((lower_limit, upper_limit))
        else:
            print("Tipo de límite inválido. Por favor, intente nuevamente.")
            return
    result = multiple_integral(expression, variables, limits)
    print("El resultado de la integral es:", result)

main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Error from parse_expr with transformed code: "Integer (2 )Symbol ('x' )**Integer (2 )"
#
# The above exception was the direct cause of the following exception:
#
# SyntaxError                               Traceback (most recent call last)
# File c:\Users\axelv\anaconda3\envs\Axel\Lib\site-packages\sympy\core\sympify.py:496, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     495     a = a.replace('\n', '')
# --> 496     expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     497 except (TokenError, SyntaxError) as exc:
#
# File c:\Users\axelv\anaconda3\envs\Axel\Lib\site-packages\sympy\parsing\sympy_parser.py:1101, in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#    1100     local_dict[i] = null
# -> 1101 raise e from ValueError(f"Error from parse_expr with transformed code: {code!r}")
#
# File c:\Users\axelv\anaconda3\envs\Axel\Lib\site-packages\sympy\parsing\sympy_parser.py:1092, in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#    1091 try:
# -> 1092     rv = eval_expr(code, local_dict, global_dict)
#    1093     # restore neutral definitions for names
#
# File c:\Users\axelv\anaconda3\envs\Axel\Lib\site-packages\sympy\parsing\sympy_parser.py:907, in eval_expr(code, local_dict, global_dict)
#     902 """
#     903 Evaluate Python code generated by ``stringify_expr``.
#     904
#     905 Generally, ``parse_expr`` should be used.
#     906 """
# --> 907 expr = eval(
#     908     code, global_dict, local_dict)  # take local objects in preference
#     909 return expr
#
# SyntaxError: invalid syntax (<string>, line 1)
#
# During handling of the above exception, another exception occurred:
#
# SympifyError                              Traceback (most recent call last)
# Cell In[10], line 36
#      33     result = multiple_integral(expression, variables, limits)
#      34     print("El resultado de la integral es:", result)
# ---> 36 main()
#
# Cell In[10], line 14, in main()
#      13 def main():
# ---> 14     expression = sp.sympify(input("Ingrese la expresión a integrar: "))
#      15     num_variables = int(input("Ingrese el número de variables de integración: "))
#      16     variables = []
#
# File c:\Users\axelv\anaconda3\envs\Axel\Lib\site-packages\sympy\core\sympify.py:498, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     496     expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     497 except (TokenError, SyntaxError) as exc:
# --> 498     raise SympifyError('could not parse %r' % a, exc)
#     500 return expr
#
# SympifyError: Sympify of expression 'could not parse '2x^2'' failed, because of exception being raised:
# SyntaxError: invalid syntax (<string>, line 1)
